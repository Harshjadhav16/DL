# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshjadhav16/DL/blob/main/DL_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import cv2
import numpy as np
import torch

# %%
# Load the YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Load the image using OpenCV
img = cv2.imread('/content/images.png')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-13 Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Convert the image to RGB (YOLO expects RGB images)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Perform inference using YOLO
results = model(img)

# %%
# Display the results
results.show()

# Print the results in a pandas dataframe
print(results.pandas().xyxy[0])
# Out:
# <PIL.Image.Image image mode=RGB size=285x177>
#           xmin       ymin        xmax        ymax  confidence  class     name
# 0    66.436348  46.105511  107.401878   80.651833    0.879729      2      car
# 1   161.812531  66.589401  216.613647  102.038475    0.827602      1  bicycle
# 2     0.000000  65.034737   77.897423  143.998566    0.796520      2      car
# 3   220.262115  44.774853  237.699265   83.627625    0.755507      0   person
# 4    96.020737  31.319403  117.069992   51.906570    0.727760      2      car
# 5    82.381943  38.888111  110.153130   57.418499    0.690434      2      car
# 6   184.585114  45.271275  206.692398   93.198189    0.581138      0   person
# 7   112.260681  25.120914  125.552750   38.023899    0.552120      2      car
# 8    86.948990  19.164572   97.729256   25.747536    0.451511      2      car
# 9    96.515953  24.038208  112.472717   32.684143    0.419025      2      car
# ...
